# %%
# !python3 server.py -p 9000
# Out:
# Sat Jul 28 20:12:03 2018 Server Starts - 0.0.0.0:9000
# =====
# Logged image: /tmp/1532779926.082183.jpg
# web_entities {
#   entity_id: "/m/0f7n6"
#   score: 0.8105999827384949
#   description: "Cadbury"
# }
# web_entities {
#   entity_id: "/m/0d19y2"
#   score: 0.70660001039505
#   description: "HIV/AIDS"
# }
# web_entities {
#   entity_id: "/m/03hnyy"
#   score: 0.7034000158309937
#   description: "Cadbury Dairy Milk"
# }
# web_entities {
#   entity_id: "/m/020vl"
#   score: 0.621399998664856
#   description: "Chocolate"
# }
# web_entities {
#   entity_id: "/m/05dbslt"
#   score: 0.6079999804496765
#   description: "HIV"
# }
# web_entities {
#   entity_id: "/m/03ywjz"
#   score: 0.602400004863739
#   description: "Cadbury Creme Egg"
# }
# web_entities {
#   entity_id: "/m/028hch"
#   score: 0.5892000198364258
#   description: "HIV-positive people"
# }
# web_entities {
#   entity_id: "/m/02wbm"
#   score: 0.5728999972343445
#   description: "Food"
# }
# web_entities {
# ...
